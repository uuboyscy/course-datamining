# %%
import pandas as pd

filename = "../resource/holding.csv"

df = pd.read_csv(filename)

# %%
df
# Out:
#            portno   report_dt  security_rank      eff_dt  percent_tna  \
# 0         2998623  2020/11/30              1  2021/01/08         2.55
# 1         2998623  2020/11/30              2  2021/01/08         1.98
# 2         2998623  2020/11/30              3  2021/01/08         1.89
# 3         2998623  2020/11/30              4  2021/01/08         1.75
# 4         2998623  2020/11/30              5  2021/01/08         1.65
# ...           ...         ...            ...         ...          ...
# 32878713  3157350  2021/11/30            428  2021/12/21         0.11
# 32878714  3157350  2021/11/30            429  2021/12/21         0.11
# 32878715  3157350  2021/11/30            429  2021/12/21         0.11
# 32878716  3157350  2021/11/30            431  2021/12/21         0.10
# 32878717  3157350  2021/11/30            432  2021/12/21         0.08
#
#           nbr_shares    market_val  \
# 0          7078982.0  3.103426e+08
# 1          3087680.0  2.412404e+08
# ...

# %% [markdown]
# ## head()

# %%
# Get the first 5 rows

df.head()
# Out:
#     portno   report_dt  security_rank      eff_dt  percent_tna  nbr_shares  \
# 0  2998623  2020/11/30              1  2021/01/08         2.55   7078982.0
# 1  2998623  2020/11/30              2  2021/01/08         1.98   3087680.0
# 2  2998623  2020/11/30              3  2021/01/08         1.89   3714760.0
# 3  2998623  2020/11/30              4  2021/01/08         1.75   2815186.0
# 4  2998623  2020/11/30              5  2021/01/08         1.65   5248941.0
#
#      market_val                    security_name     cusip
# 0  3.103426e+08                GENERAL MOTORS CO  37045V10
# 1  2.412404e+08   COGNIZANT TECHNOLOGY SOLS CORP  19244610
# 2  2.296836e+08  MORGAN STANLEY DEAN WITTER & CO  61744644
# 3  2.132503e+08  PHILIP MORRIS INTERNATIONAL INC  71817210
# 4  2.011394e+08                      CORTEVA INC  22052L10

# %%
# Get the first n rows

n = 10
df.head(n)
# Out:
#     portno   report_dt  security_rank      eff_dt  percent_tna  nbr_shares  \
# 0  2998623  2020/11/30              1  2021/01/08         2.55   7078982.0
# 1  2998623  2020/11/30              2  2021/01/08         1.98   3087680.0
# 2  2998623  2020/11/30              3  2021/01/08         1.89   3714760.0
# 3  2998623  2020/11/30              4  2021/01/08         1.75   2815186.0
# 4  2998623  2020/11/30              5  2021/01/08         1.65   5248941.0
# 5  2998623  2020/11/30              6  2021/01/08         1.64    866386.0
# 6  2998623  2020/11/30              7  2021/01/08         1.63   2194727.0
# 7  2998623  2020/11/30              8  2021/01/08         1.60   5045923.0
# 8  2998623  2020/11/30              9  2021/01/08         1.59   1403360.0
# 9  2998623  2020/11/30             10  2021/01/08         1.54   3065766.0
#
#      market_val                     security_name     cusip
# 0  3.103426e+08                 GENERAL MOTORS CO  37045V10
# ...

# %% [markdown]
# ## tail()

# %%
# Get last 5 rows

df.tail()
# Out:
#            portno   report_dt  security_rank      eff_dt  percent_tna  \
# 32878713  3157350  2021/11/30            428  2021/12/21         0.11
# 32878714  3157350  2021/11/30            429  2021/12/21         0.11
# 32878715  3157350  2021/11/30            429  2021/12/21         0.11
# 32878716  3157350  2021/11/30            431  2021/12/21         0.10
# 32878717  3157350  2021/11/30            432  2021/12/21         0.08
#
#           nbr_shares  market_val  \
# 32878713     25000.0    22294.75
# 32878714     25000.0    21480.50
# 32878715     25000.0    21484.00
# 32878716     25000.0    19187.38
# 32878717     25000.0    14971.88
#
#                                           security_name     cusip
# 32878713     Bausch Health Companies Inc 5% 30-JAN-2028  071734AH
# 32878714  Bausch Health Companies Inc 5.25% 30-JAN-2030  071734AJ
# 32878715     Bausch Health Companies Inc 5% 15-FEB-2029  071734AM
# 32878716                        Endo DAC 6% 30-JUN-2028  29273DAC
# ...

# %%
# Get last n rows

n = 10
df.tail(n)
# Out:
#            portno   report_dt  security_rank      eff_dt  percent_tna  \
# 32878708  3157350  2021/11/30            423  2021/12/21         0.12
# 32878709  3157350  2021/11/30            424  2021/12/21         0.12
# 32878710  3157350  2021/11/30            425  2021/12/21         0.12
# 32878711  3157350  2021/11/30            426  2021/12/21         0.11
# 32878712  3157350  2021/11/30            427  2021/12/21         0.11
# 32878713  3157350  2021/11/30            428  2021/12/21         0.11
# 32878714  3157350  2021/11/30            429  2021/12/21         0.11
# 32878715  3157350  2021/11/30            429  2021/12/21         0.11
# 32878716  3157350  2021/11/30            431  2021/12/21         0.10
# 32878717  3157350  2021/11/30            432  2021/12/21         0.08
#
#           nbr_shares  market_val  \
# 32878708     25000.0    22810.50
# 32878709     25000.0    22726.50
# 32878710     25000.0    22700.00
# 32878711     25000.0    22685.13
# ...

# %%
# Get certain rows

df[444:449]
# Out:
#       portno   report_dt  security_rank      eff_dt  percent_tna  nbr_shares  \
# 444  2998809  2020/11/30             17  2021/01/08         1.96   1542737.0
# 445  2998809  2020/11/30             18  2021/01/08         1.88   1883515.0
# 446  2998809  2020/11/30             19  2021/01/08         1.80    260036.0
# 447  2998809  2020/11/30             20  2021/01/08         1.74    150444.0
# 448  2998809  2020/11/30             21  2021/01/08         1.71    725931.0
#
#       market_val                     security_name     cusip
# 444  39154665.06            EQUITABLE HOLDINGS INC  29452E10
# 445  37632629.70                     CARNIVAL CORP  14365830
# 446  35903170.52  P N C FINANCIAL SERVICES GRP INC  69347510
# 447  34778139.48                       CUMMINS INC  23102110
# 448  34278461.82             LINCOLN NATIONAL CORP  53418710

# %% [markdown]
# ## loc[:, :]

# %%
# Get certain rows and columns by name

df.loc[[1,3,5,7], :]
# Out:
#     portno   report_dt  security_rank      eff_dt  percent_tna  nbr_shares  \
# 1  2998623  2020/11/30              2  2021/01/08         1.98   3087680.0
# 3  2998623  2020/11/30              4  2021/01/08         1.75   2815186.0
# 5  2998623  2020/11/30              6  2021/01/08         1.64    866386.0
# 7  2998623  2020/11/30              8  2021/01/08         1.60   5045923.0
#
#      market_val                     security_name     cusip
# 1  2.412404e+08    COGNIZANT TECHNOLOGY SOLS CORP  19244610
# 3  2.132503e+08   PHILIP MORRIS INTERNATIONAL INC  71817210
# 5  1.997713e+08           GOLDMAN SACHS GROUP INC  38141G10
# 7  1.939653e+08  AMERICAN INTERNATIONAL GROUP INC  02687478

# %%
# Get certain rows and columns

df.loc[[1, 3, 5, 7], "portno":"market_val"]
# Out:
#     portno   report_dt  security_rank      eff_dt  percent_tna  nbr_shares  \
# 1  2998623  2020/11/30              2  2021/01/08         1.98   3087680.0
# 3  2998623  2020/11/30              4  2021/01/08         1.75   2815186.0
# 5  2998623  2020/11/30              6  2021/01/08         1.64    866386.0
# 7  2998623  2020/11/30              8  2021/01/08         1.60   5045923.0
#
#      market_val
# 1  2.412404e+08
# 3  2.132503e+08
# 5  1.997713e+08
# 7  1.939653e+08

# %% [markdown]
# ## iloc[:, :]

# %%
# Get certain rows and columns by index

df.iloc[[1,3,5,7], :]
# Out:
#     portno   report_dt  security_rank      eff_dt  percent_tna  nbr_shares  \
# 1  2998623  2020/11/30              2  2021/01/08         1.98   3087680.0
# 3  2998623  2020/11/30              4  2021/01/08         1.75   2815186.0
# 5  2998623  2020/11/30              6  2021/01/08         1.64    866386.0
# 7  2998623  2020/11/30              8  2021/01/08         1.60   5045923.0
#
#      market_val                     security_name     cusip
# 1  2.412404e+08    COGNIZANT TECHNOLOGY SOLS CORP  19244610
# 3  2.132503e+08   PHILIP MORRIS INTERNATIONAL INC  71817210
# 5  1.997713e+08           GOLDMAN SACHS GROUP INC  38141G10
# 7  1.939653e+08  AMERICAN INTERNATIONAL GROUP INC  02687478

# %%
df.iloc[[1, 3, 5, 7], "portno":"market_val"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 df.iloc[[1, 3, 5, 7], "portno":"market_val"]
#
# File ~/PycharmProjects/datamining-course/venv/lib/python3.8/site-packages/pandas/core/indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     959     if self._is_scalar_access(key):
#     960         return self.obj._get_value(*key, takeable=self._takeable)
# --> 961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#     964     axis = self.axis or 0
#
# File ~/PycharmProjects/datamining-course/venv/lib/python3.8/site-packages/pandas/core/indexing.py:1462, in _iLocIndexer._getitem_tuple(self, tup)
#    1459 with suppress(IndexingError):
#    1460     return self._getitem_lowerdim(tup)
# -> 1462 return self._getitem_tuple_same_dim(tup)
#
# ...

# %%
df.iloc[[1, 3, 5, 7], 0:7]
# Out:
#     portno   report_dt  security_rank      eff_dt  percent_tna  nbr_shares  \
# 1  2998623  2020/11/30              2  2021/01/08         1.98   3087680.0
# 3  2998623  2020/11/30              4  2021/01/08         1.75   2815186.0
# 5  2998623  2020/11/30              6  2021/01/08         1.64    866386.0
# 7  2998623  2020/11/30              8  2021/01/08         1.60   5045923.0
#
#      market_val
# 1  2.412404e+08
# 3  2.132503e+08
# 5  1.997713e+08
# 7  1.939653e+08

# %% [markdown]
# ## columns and index

# %%
# Get columns

df.columns
# Out:
# Index(['portno', 'report_dt', 'security_rank', 'eff_dt', 'percent_tna',
#        'nbr_shares', 'market_val', 'security_name', 'cusip'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=32878718, step=1)

# %% [markdown]
# # dtypes

# %%
df.dtypes
# Out:
# portno            object
# report_dt         object
# security_rank      int64
# eff_dt            object
# percent_tna      float64
# nbr_shares       float64
# market_val       float64
# security_name     object
# cusip             object
# dtype: object

# %%
df["portno"].dtype
# Out:
# dtype('O')

# %%
df["security_rank"].dtype
# Out:
# dtype('int64')

# %%
df["market_val"].dtype
# Out:
# dtype('float64')

# %% [markdown]
# # unique()

# %%
df["portno"].unique()
# Out:
# array(['2998623', '2998638', '2998809', ..., '3157332', '315733e',
#        '3157350'], dtype=object)

# %%
type(df["portno"].unique())
# Out:
# numpy.ndarray

# %% [markdown]
# # mean()

# %%
df["nbr_shares"].mean()
# Out:
# 41548315.25043799

# %%
df["security_rank"].mean()
# Out:
# 1077.9147216749752

# %%
df["percent_tna"].mean()
# Out:
# 0.2945002086151897

# %%
df["market_val"].mean()
# Out:
# 8366759.8750717705

# %%
df["cusip"].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [25], in <cell line: 1>()
# ----> 1 df["cusip"].mean()
#
# File ~/PycharmProjects/datamining-course/venv/lib/python3.8/site-packages/pandas/core/generic.py:11117, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11099 @doc(
#   11100     _num_doc,
#   11101     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11115     **kwargs,
#   11116 ):
# > 11117     return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#
# File ~/PycharmProjects/datamining-course/venv/lib/python3.8/site-packages/pandas/core/generic.py:10687, in NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10679 def mean(
#   10680     self,
#   10681     axis: Axis | None | lib.NoDefault = lib.no_default,
#    (...)
#   10685     **kwargs,
# ...

# %%
df[["nbr_shares", "security_rank", "percent_tna", "market_val"]].mean()
# Out:
# nbr_shares       4.154832e+07
# security_rank    1.077915e+03
# percent_tna      2.945002e-01
# market_val       8.366760e+06
# dtype: float64

# %%
df[["nbr_shares", "security_rank", "percent_tna", "market_val", "cusip"]].mean()
# Out:
# /var/folders/bv/8bbkzq895db366kq27vw262r0000gn/T/ipykernel_47226/3204749079.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df[["nbr_shares", "security_rank", "percent_tna", "market_val", "cusip"]].mean()
# nbr_shares       4.154832e+07
# security_rank    1.077915e+03
# percent_tna      2.945002e-01
# market_val       8.366760e+06
# dtype: float64

# %% [markdown]
# ## value_counts

# %%
df["portno"].value_counts()
# Out:
# 3066654    223027
# 3086928    185325
# 306841b    181445
# 3100110    127403
# 306920d    120721
#             ...
# 3092553         1
# 3069210         1
# 3065319         1
# 3077046         1
# 3078942         1
# Name: portno, Length: 11920, dtype: int64

# %%
df2 = pd.DataFrame(
    {
        'num_legs': [2, 4, 4, 6],
        'num_wings': [2, 0, 0, 0]
    },
    index=['falcon', 'dog', 'cat', 'ant']
)
df2
# Out:
#         num_legs  num_wings
# falcon         2          2
# dog            4          0
# cat            4          0
# ant            6          0

# %%
df2.value_counts()
# Out:
# num_legs  num_wings
# 4         0            2
# 2         2            1
# 6         0            1
# dtype: int64

# %%
type(df2.value_counts())
# Out:
# pandas.core.series.Series

# %%
df2.value_counts().index
# Out:
# MultiIndex([(4, 0),
#             (2, 2),
#             (6, 0)],
#            names=['num_legs', 'num_wings'])

# %%
df.value_counts()
# Out:
# portno   report_dt   security_rank  eff_dt      percent_tna  nbr_shares  market_val    security_name                                                   cusip
# 2998623  2020/11/30  1              2021/01/08  2.55         7078982.0   3.103426e+08  GENERAL MOTORS CO                                               37045V10    1
# 309473d  2021/04/30  1397           2021/06/07  0.00         872000.0    5.560842e+04  South Africa, Republic of (Government) 8% 31-JAN-2030           S69124VP    1
#                      1428           2021/06/07  0.00         26639.0     2.902364e+04  Freddie Mac 01-JUL-2042 Q09739                                  3132GVEL    1
#                      1427           2021/06/07  0.00         30000.0     3.011460e+04  Escambia County Health Facilities Authority 3.607% 15-AUG-2040  296110GG    1
#                      1424           2021/06/07  0.00         31000.0     3.122589e+04  Martin Marietta Materials Inc 2.5% 15-MAR-2030                  573284AV    1
# ...

# %%
df.value_counts().index
# Out:
# MultiIndex([('2998623', '2020/11/30',    1, '2021/01/08', 2.55, ...),
#             ('309473d', '2021/04/30', 1397, '2021/06/07',  0.0, ...),
#             ('309473d', '2021/04/30', 1428, '2021/06/07',  0.0, ...),
#             ('309473d', '2021/04/30', 1427, '2021/06/07',  0.0, ...),
#             ('309473d', '2021/04/30', 1424, '2021/06/07',  0.0, ...),
#             ('309473d', '2021/04/30', 1424, '2021/06/07',  0.0, ...),
#             ('309473d', '2021/04/30', 1422, '2021/06/07',  0.0, ...),
#             ('309473d', '2021/04/30', 1422, '2021/06/07',  0.0, ...),
#             ('309473d', '2021/04/30', 1418, '2021/06/21',  0.0, ...),
#             ('309473d', '2021/04/30', 1418, '2021/06/07',  0.0, ...),
#             ...
#             ('3074208', '2021/10/31',    9, '2021/12/07', 0.94, ...),
#             ('3074208', '2021/10/31',    8, '2021/12/07', 0.98, ...),
#             ('3074208', '2021/10/31',    7, '2021/12/07', 0.99, ...),
# ...

# %% [markdown]
# ## describe()

# %%
df.describe()
# Out:
#        security_rank   percent_tna    nbr_shares    market_val
# count   3.287872e+07  3.287872e+07  3.287872e+07  3.287872e+07
# mean    1.077915e+03  2.945002e-01  4.154832e+07  8.366760e+06
# std     1.793852e+03  1.651244e+00  8.185030e+09  1.376690e+08
# min     1.000000e+00 -2.628000e+02 -1.188360e+13 -3.157247e+10
# 25%     1.310000e+02  1.000000e-02  8.000000e+03  9.254227e+04
# 50%     4.230000e+02  4.000000e-02  1.000000e+05  5.251210e+05
# 75%     1.228000e+03  1.900000e-01  8.250000e+05  2.523780e+06
# max     1.866500e+04  3.822500e+02  9.665837e+12  7.359335e+10

# %% [markdown]
# ## Filter data

# %%
filter_portno_2998623 = df["portno"] == "2998623"
filter_portno_2998623
# Out:
# 0            True
# 1            True
# 2            True
# 3            True
# 4            True
#             ...
# 32878713    False
# 32878714    False
# 32878715    False
# 32878716    False
# 32878717    False
# Name: portno, Length: 32878718, dtype: bool

# %%
df[filter_portno_2998623]
# Out:
#            portno   report_dt  security_rank      eff_dt  percent_tna  \
# 0         2998623  2020/11/30              1  2021/01/08         2.55
# 1         2998623  2020/11/30              2  2021/01/08         1.98
# 2         2998623  2020/11/30              3  2021/01/08         1.89
# 3         2998623  2020/11/30              4  2021/01/08         1.75
# 4         2998623  2020/11/30              5  2021/01/08         1.65
# ...           ...         ...            ...         ...          ...
# 30001404  2998623  2021/10/31            339  2021/12/07         0.00
# 30001405  2998623  2021/10/31            339  2021/12/07         0.00
# 30001406  2998623  2021/10/31            339  2021/12/07         0.00
# 30001407  2998623  2021/10/31            339  2021/12/07         0.00
# 30001408  2998623  2021/10/31            339  2021/12/07         0.00
#
#           nbr_shares    market_val                        security_name  \
# ...

# %%
filter_reportdt_20210131 = df["report_dt"] == "2021/01/31"

# %%
df[filter_portno_2998623 & filter_reportdt_20210131]
# Out:
#           portno   report_dt  security_rank      eff_dt  percent_tna  \
# 4933836  2998623  2021/01/31              1  2021/03/08         2.72
# 4933837  2998623  2021/01/31              4  2021/03/08         1.89
# 4933838  2998623  2021/01/31              5  2021/03/08         1.85
# 4933839  2998623  2021/01/31              6  2021/03/08         1.72
# 4933840  2998623  2021/01/31              7  2021/03/08         1.57
# ...          ...         ...            ...         ...          ...
# 5980019  2998623  2021/01/31            347  2021/03/23         0.00
# 5980020  2998623  2021/01/31            347  2021/03/23         0.00
# 5980021  2998623  2021/01/31            347  2021/03/23         0.00
# 5980022  2998623  2021/01/31            347  2021/03/23         0.00
# 5980023  2998623  2021/01/31            347  2021/03/23         0.00
#
#          nbr_shares    market_val                          security_name  \
# ...
