# %%
import pandas as pd

filename = "holding.csv"

# %%
df = pd.read_csv(filename)
df
# Out:
#            portno   report_dt  security_rank      eff_dt  percent_tna  \
# 0         2998623  2020/11/30              1  2021/01/08         2.55
# 1         2998623  2020/11/30              2  2021/01/08         1.98
# 2         2998623  2020/11/30              3  2021/01/08         1.89
# 3         2998623  2020/11/30              4  2021/01/08         1.75
# 4         2998623  2020/11/30              5  2021/01/08         1.65
# ...           ...         ...            ...         ...          ...
# 32878713  3157350  2021/11/30            428  2021/12/21         0.11
# 32878714  3157350  2021/11/30            429  2021/12/21         0.11
# 32878715  3157350  2021/11/30            429  2021/12/21         0.11
# 32878716  3157350  2021/11/30            431  2021/12/21         0.10
# 32878717  3157350  2021/11/30            432  2021/12/21         0.08
#
#           nbr_shares    market_val  \
# 0          7078982.0  3.103426e+08
# 1          3087680.0  2.412404e+08
# ...

# %%
"""
Show data size in each group
"""

df.groupby("portno").size()
# Out:
# portno
# 2998623    4155
# 2998638     929
# 2998809     862
# 2998821     629
# 2998923     420
#            ...
# 315733b      16
# 315733e     363
# 3157347       5
# 315734a       3
# 3157350     428
# Length: 11920, dtype: int64

# %%
"""
Summation of number of each column
"""

df.groupby("portno").sum()
# Out:
#          security_rank  percent_tna    nbr_shares    market_val
# portno
# 2998623         722749      1198.27  5.251658e+10  1.545583e+11
# 2998638          36547      1199.13  3.745789e+09  1.130269e+11
# 2998809          31611      1220.67  5.829471e+09  5.861381e+10
# 2998821          16809      1200.38  9.877622e+08  2.259974e+10
# 2998923           7562      1199.80  1.875752e+08  5.320404e+09
# ...                ...          ...           ...           ...
# 315733b            137        99.73  1.783122e+07  2.601732e+07
# 315733e          66053       525.90  2.659001e+08  2.762602e+08
# 3157347             19        55.06  6.300062e+06  6.299271e+06
# 315734a              6       148.11  5.402436e+06  1.525456e+07
# 3157350          92037        99.55  1.927648e+07  1.964126e+07
#
# [11920 rows x 4 columns]

# %%
"""
Summation of specific column's number
"""

df.groupby("portno")["nbr_shares"].sum()
# Out:
# portno
# 2998623    5.251658e+10
# 2998638    3.745789e+09
# 2998809    5.829471e+09
# 2998821    9.877622e+08
# 2998923    1.875752e+08
#                ...
# 315733b    1.783122e+07
# 315733e    2.659001e+08
# 3157347    6.300062e+06
# 315734a    5.402436e+06
# 3157350    1.927648e+07
# Name: nbr_shares, Length: 11920, dtype: float64

# %%
df.groupby("portno").get_group("315733b")
# Out:
#            portno   report_dt  security_rank      eff_dt  percent_tna  \
# 31718332  315733b  2021/11/30              1  2021/12/07         8.04
# 31718333  315733b  2021/11/30              2  2021/12/07         8.01
# 31718334  315733b  2021/11/30              3  2021/12/07         7.39
# 31718335  315733b  2021/11/30              4  2021/12/07         7.34
# 31718336  315733b  2021/11/30              5  2021/12/07         7.34
# 31718337  315733b  2021/11/30              6  2021/12/07         7.23
# 31718338  315733b  2021/11/30              7  2021/12/07         7.14
# 31718339  315733b  2021/11/30              8  2021/12/07         7.10
# 31718340  315733b  2021/11/30              9  2021/12/07         7.03
# 31718341  315733b  2021/11/30             10  2021/12/07         6.87
# 31718342  315733b  2021/11/30             11  2021/12/07         6.73
# 31718343  315733b  2021/11/30             12  2021/12/07         6.24
# ...

# %%
df.groupby(["portno", "security_name"]).size()
# Out:
# portno   security_name
# 2998623  10YR TNotes DEC1                              3
#          10YR TNotes JUN1                              3
#          10YR TNotes MAR1                              3
#          10YR TNotes SEP1                              3
#          5YR T NOTES DEC1                              3
#                                                       ..
# 3157350  Zayo Group Holdings Inc 4% 01-MAR-2027        1
#          Ziff Davis Inc 4.625% 15-OCT-2030             1
#          Ziggo BV 5.5% 15-JAN-2027                     1
#          iHeartCommunications Inc 4.75% 15-JAN-2028    1
#          iHeartCommunications Inc 5.25% 15-AUG-2027    1
# Length: 5656033, dtype: int64

# %%
df.groupby(["portno", "security_name"]).sum()
# Out:
#                                                     security_rank  \
# portno  security_name
# 2998623 10YR TNotes DEC1                                     1024
#         10YR TNotes JUN1                                     1035
#         10YR TNotes MAR1                                     1047
#         10YR TNotes SEP1                                     1049
#         5YR T NOTES DEC1                                     1021
# ...                                                           ...
# 3157350 Zayo Group Holdings Inc 4% 01-MAR-2027                192
#         Ziff Davis Inc 4.625% 15-OCT-2030                     314
#         Ziggo BV 5.5% 15-JAN-2027                               7
#         iHeartCommunications Inc 4.75% 15-JAN-2028            345
#         iHeartCommunications Inc 5.25% 15-AUG-2027            297
#
#                                                     percent_tna  nbr_shares  \
# portno  security_name
# ...

# %%
df.groupby(["security_name", "portno"]).sum()
# Out:
#                                                             security_rank  \
# security_name                                      portno
# % PERP SR: 2020                                    3076806            286
#                                                    3076809           1753
# &Do Holdings Co Ltd ORD                            3062403           6850
#                                                    307292a           1976
#                                                    3082602            754
# ...                                                                   ...
# voestalpine AG ORD                                 3155349           2487
#                                                    3155532            317
#                                                    3155835           2541
# want want China Holdings Ltd Swap Bullet           3102348           1190
# Pinal County Community College District 5.000%... 3065604           1579
#
# ...

# %%
df.groupby(["security_name"]).sum()
# Out:
#                                                     security_rank  \
# security_name
# % PERP SR: 2020                                              2039
# &Do Holdings Co Ltd ORD                                     10362
# .09% 04-FEB-2021                                               73
# .1% 03-JUN-2021                                                75
# .11% 01-JAN-2051                                             1009
# ...                                                           ...
# va Q tec AG ORD                                            124619
# va Q tec AG Swap Bullet                                       269
# voestalpine AG ORD                                        2112320
# want want China Holdings Ltd Swap Bullet                     1190
# Pinal County Community College District 5.000%...           1579
#
#                                                     percent_tna  nbr_shares  \
# security_name
# ...

# %%
df
# Out:
#            portno   report_dt  security_rank      eff_dt  percent_tna  \
# 0         2998623  2020/11/30              1  2021/01/08         2.55
# 1         2998623  2020/11/30              2  2021/01/08         1.98
# 2         2998623  2020/11/30              3  2021/01/08         1.89
# 3         2998623  2020/11/30              4  2021/01/08         1.75
# 4         2998623  2020/11/30              5  2021/01/08         1.65
# ...           ...         ...            ...         ...          ...
# 32878713  3157350  2021/11/30            428  2021/12/21         0.11
# 32878714  3157350  2021/11/30            429  2021/12/21         0.11
# 32878715  3157350  2021/11/30            429  2021/12/21         0.11
# 32878716  3157350  2021/11/30            431  2021/12/21         0.10
# 32878717  3157350  2021/11/30            432  2021/12/21         0.08
#
#           nbr_shares    market_val  \
# 0          7078982.0  3.103426e+08
# 1          3087680.0  2.412404e+08
# ...

# %%
df[df["portno"] == "2998623"]
# Out:
#            portno   report_dt  security_rank      eff_dt  percent_tna  \
# 0         2998623  2020/11/30              1  2021/01/08         2.55
# 1         2998623  2020/11/30              2  2021/01/08         1.98
# 2         2998623  2020/11/30              3  2021/01/08         1.89
# 3         2998623  2020/11/30              4  2021/01/08         1.75
# 4         2998623  2020/11/30              5  2021/01/08         1.65
# ...           ...         ...            ...         ...          ...
# 30001404  2998623  2021/10/31            339  2021/12/07         0.00
# 30001405  2998623  2021/10/31            339  2021/12/07         0.00
# 30001406  2998623  2021/10/31            339  2021/12/07         0.00
# 30001407  2998623  2021/10/31            339  2021/12/07         0.00
# 30001408  2998623  2021/10/31            339  2021/12/07         0.00
#
#           nbr_shares    market_val                        security_name  \
# ...

# %%
df[df["portno"] == "2998623"].report_dt.unique()
# Out:
# array(['2020/11/30', '2020/12/31', '2021/01/31', '2021/02/28',
#        '2021/03/31', '2021/04/30', '2021/05/31', '2021/06/30',
#        '2021/07/31', '2021/08/31', '2021/09/30', '2021/10/31'],
#       dtype=object)

# %%
df[df["portno"] == "2998623"].eff_dt.unique()
# Out:
# array(['2021/01/08', '2021/02/05', '2021/02/19', '2021/03/08',
#        '2021/03/23', '2021/04/09', '2021/04/23', '2021/05/10',
#        '2021/05/24', '2021/06/07', '2021/06/21', '2021/07/07',
#        '2021/07/22', '2021/08/09', '2021/09/07', '2021/10/07',
#        '2021/10/21', '2021/11/05', '2021/11/19', '2021/12/07'],
#       dtype=object)

# %%
df[df["portno"] == "2998623"].groupby("eff_dt").sum()
# Out:
#             security_rank  percent_tna    nbr_shares    market_val
# eff_dt
# 2021/01/08          61888        99.79  3.817768e+09  1.213476e+10
# 2021/02/05          61472        99.20  3.864276e+09  1.226047e+10
# 2021/02/19             72         0.56  3.054300e+07  6.951946e+07
# 2021/03/08           6384        70.69  9.649015e+08  8.516031e+09
# 2021/03/23          53751        29.08  2.971574e+09  3.517922e+09
# 2021/04/09          56668        97.12  3.638548e+09  1.223805e+10
# 2021/04/23           1067         2.68  3.422472e+08  3.395333e+08
# 2021/05/10          60960        99.96  4.630649e+09  1.289602e+10
# 2021/05/24            206         0.05  6.744000e+06  6.749569e+06
# 2021/06/07          60172        99.93  4.602999e+09  1.325502e+10
# 2021/06/21            293         0.03  3.630000e+06  3.709301e+06
# 2021/07/07          61219        98.90  4.496279e+09  1.325307e+10
# 2021/07/22            282         1.07  7.509964e+06  1.428888e+08
# ...

# %%
df[df["portno"] == "2998623"].groupby("report_dt").sum()
# Out:
#             security_rank  percent_tna    nbr_shares    market_val
# report_dt
# 2020/11/30          61888        99.79  3.817768e+09  1.213476e+10
# 2020/12/31          61544        99.76  3.894819e+09  1.232999e+10
# 2021/01/31          60135        99.77  3.936475e+09  1.203395e+10
# 2021/02/28          57735        99.80  3.980795e+09  1.257758e+10
# 2021/03/31          61166       100.01  4.637393e+09  1.290277e+10
# 2021/04/30          60465        99.96  4.606629e+09  1.325873e+10
# 2021/05/31          61501        99.97  4.503789e+09  1.339596e+10
# 2021/06/30          61534        99.78  4.673745e+09  1.324652e+10
# 2021/07/31          61189        99.88  4.569438e+09  1.314789e+10
# 2021/08/31          60836        99.76  4.612223e+09  1.323175e+10
# 2021/09/30          57369        99.89  4.630959e+09  1.294457e+10
# 2021/10/31          57387        99.90  4.652550e+09  1.335381e+10

# %%
df[df["portno"] == "2998623"].groupby("report_dt").sum().sort_values("percent_tna", ascending=False)
# Out:
#             security_rank  percent_tna    nbr_shares    market_val
# report_dt
# 2021/03/31          61166       100.01  4.637393e+09  1.290277e+10
# 2021/05/31          61501        99.97  4.503789e+09  1.339596e+10
# 2021/04/30          60465        99.96  4.606629e+09  1.325873e+10
# 2021/10/31          57387        99.90  4.652550e+09  1.335381e+10
# 2021/09/30          57369        99.89  4.630959e+09  1.294457e+10
# 2021/07/31          61189        99.88  4.569438e+09  1.314789e+10
# 2021/02/28          57735        99.80  3.980795e+09  1.257758e+10
# 2020/11/30          61888        99.79  3.817768e+09  1.213476e+10
# 2021/06/30          61534        99.78  4.673745e+09  1.324652e+10
# 2021/01/31          60135        99.77  3.936475e+09  1.203395e+10
# 2020/12/31          61544        99.76  3.894819e+09  1.232999e+10
# 2021/08/31          60836        99.76  4.612223e+09  1.323175e+10

# %%
df[df["portno"] == "2998623"].groupby("report_dt").head()
# Out:
#            portno   report_dt  security_rank      eff_dt  percent_tna  \
# 0         2998623  2020/11/30              1  2021/01/08         2.55
# 1         2998623  2020/11/30              2  2021/01/08         1.98
# 2         2998623  2020/11/30              3  2021/01/08         1.89
# 3         2998623  2020/11/30              4  2021/01/08         1.75
# 4         2998623  2020/11/30              5  2021/01/08         1.65
# 2558138   2998623  2020/12/31              1  2021/02/05         2.30
# 2558139   2998623  2020/12/31              2  2021/02/05         1.97
# 2558140   2998623  2020/12/31              3  2021/02/05         1.87
# 2558141   2998623  2020/12/31              4  2021/02/05         1.86
# 2558142   2998623  2020/12/31              5  2021/02/05         1.82
# 4933836   2998623  2021/01/31              1  2021/03/08         2.72
# 4933837   2998623  2021/01/31              4  2021/03/08         1.89
# ...

# %%
help(pd.DataFrame.sort_values)
# Out:
# Help on function sort_values in module pandas.core.frame:
#
# sort_values(self, by, axis: 'Axis' = 0, ascending=True, inplace: 'bool' = False, kind: 'str' = 'quicksort', na_position: 'str' = 'last', ignore_index: 'bool' = False, key: 'ValueKeyFunc' = None)
#     Sort by the values along either axis.
#
#     Parameters
#     ----------
#             by : str or list of str
#                 Name or list of names to sort by.
#
#                 - if `axis` is 0 or `'index'` then `by` may contain index
#                   levels and/or column labels.
#                 - if `axis` is 1 or `'columns'` then `by` may contain column
#                   levels and/or index labels.
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#          Axis to be sorted.
#     ascending : bool or list of bool, default True
#          Sort ascending vs. descending. Specify list for multiple sort
#          orders.  If this is a list of bools, must match the length of
#          the by.
# ...
